# %% [markdown]
# <img src="https://www.ikiam.edu.ec/img/logo-ikiam-grey.png" width=300 height=240 />
#
# # EXAMEN PARCIAL 1
#
# ## GBI6-2021II: BIOINFORMÁTICA
#
# **Apellidos, Nombres** <--- NETO IBARRA SEBASTIAN ALEJANDRO
#
# **11-01-2021**

# %% [markdown]
# <font color='red'>NO AGREGUE NUEVAS CELDAS, UTILICE ÚNICAMENTE LAS QUE ESTÁN CREADAS</font>

# %% [markdown]
# # 1. UNIX
#
# ## Ejercicio 1
# Para esta pregunta debe realizar previamente lo siguiente:
#
# - Imprimir el directorio de trabajo actual
# - Crear un directorio test1
# - No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# - Crear el archivo test1.txt
# - Guardar el texto Hola GBI6 en un archivo test2.txt
# - Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
#
# Luego seleccione la instrucción que permite enlistar el contenido (sin detalles) del directorio test1
#
# <img src="./Pregunta_1.png" width=600 height=450 />
#
#
# ## Ejercicio 2
# Seleccione la opción el código que imprime el texto: Hola GBI6
#
#
# <img src="./Pregunta_2.png/" width=600 height=450 />
#
#
# ## Ejercicio 3
# Para esta pregunta debe realizar previamente lo siguiente:
#
# - Imprimir el directorio de trabajo actual
# - Crear un directorio test1
# - No cambie de directorio, pero los items 4, 5 y 6 deben guardarse en el directorio creado en el paso 2.
# - Crear el archivo test1.txt
# - Guardar el texto Hola GBI6 en un archivo test2.txt
# - Guardar la instrucción print("Hola GBI6")  en el archivo test1.py
#
# Luego seleccione la instrucción que enlista los archivos del directorio test1 y luego borra test1.py del directorio test1
#
# <img src="./Pregunta_3.png" width=600 height=450 />
#
# Primero: No se repitió la creación de los archivos y procedimiento puesto que es lo que se realizó en el primer ejercicio. Segundo: hay otras opciones de codigo que enlistan (pero detallando) y luego borran el text1.py, pero como ya se usó un remove esto no se puede evidenciar, estas son:
# - ls -lh test1 ; rm test1/test1.py
# - ls -l test1 ; rm test1/test1.py
#
# ## Ejercicio 4
# Escriba aquí el enunciado

# %%
# Coloque aquí su video del ejercicio 4
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/9ck5iEP03g4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/9ck5iEP03g4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Escriba aquí alguna explicación del ejercicio 4 si lo considera necesario (borre esta línea cuando finalice)
#
# ## Ejercicio 5
# Escriba aquí el enunciado

# %%
# Coloque aquí su video del ejercicio 5
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/3XlZWpLwvvo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3XlZWpLwvvo" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Escriba aquí alguna explicación del ejercicio 5 si lo considera necesario (borre esta línea cuando finalice)
#
# # 2. CONTROL DE LA VERSIÓN
# ## Pregunta 6
# 1. Cree en GitHub un repositorio de nombre ```GBI6_ExamenParcial1```.
# 2. Cree un archivo ```Readme.md``` que debe tener lo siguiente:
# - Datos personales
# - Características del computador
# - Programas utilizados
# - Explicación de la data utilizada
#
#
# ## Pregunta 7
# 1. Cada vez que resuelva un ejercicio (del 1 al 10), utilizando Git Bash, GitHub Desktop o Atom realice un *git push* con el mensaje:
#
#
# <font color='red'>Apellido Nombre ha resuelto el ejercicio 1</font> % Cambie con sus apellidos y nombres; y con el número de ejercicio que corresponda
#
# 2. Coloque aquí las capturas de pantalla para cada git push realizado desde Git Bash, GitHub Desktop o Atom.
#
# - Control de versión ejercicio 1
#
# <img src="./Pregunta_7_a.png" width=600 height=450 />
#
# - Control de versión ejercicio 2
#
# <img src="./Pregunta_7_b.png" width=600 height=450 />
#
# - Control de versión ejercicio 3
#
# <img src="./Pregunta_7_c.png" width=600 height=450 />
#
# - Control de versión ejercicio 4
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 5
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 8
#
# <img src="./Pregunta_7_f.png" width=600 height=450 />
#
# - Control de versión ejercicio 9
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
# - Control de versión ejercicio 10
#
# <img src="data/ejemplo_unix.jpg" width=600 height=450 />
#
#
# 3. Cree un directorio de nombre ```data``` donde deben estar guardados: (i) la data utilizada y (ii) las capturas de pantalla de los ejercicios 1 al 3 y los git push del ejercicio 1 al 10 (en total debe tener 13 imágenes).
# 4. Inserte aquí el enlace de su repositorio (válido para el ejercicio 6 y 7): [GitHub Repository: GBI6_ExamenParcial1](https://github.com/gualapuromoises/2021_gbi6.git) (este enlace es de ejemplo)

# %% [markdown]
# # 3. INTRODUCCIÓN A PYTHON
#
# ## Ejercicio 8
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# Descargue la data "SI Table 1" (10080Table1.xls) de la página https://www.pnas.org/content/suppl/2006/12/27/0610080104.DC1. Esta data corresponde a algunas características de sueño de mamíferos. Seleccione los 10 primeros registros de la columna "Total sleep time, hr" y cree una lista de nombre lista1.
#
# Relaciones los códigos y las respuestas que salen al ejecutar.

# %%
#Resolución:
# Creación de la lista:

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1] # Creación de la lista con los diez primeros datos de Total sleep time, hr

#Creación de un verificador para conocer si se añadieron 10 datos: 

if len(lista1) == 10:
    print("se añadieron los diez primeros datos") # nos avisará si añadimos 10 datos
else:
    print("no se añadieron 10 datos revisar la lista") # nos dirá si no añadimos 10 datos

# corrida de códigos pedidos en moodle:

print("el comando lista1[8:] devuelve:", lista1[8:])# visualiza los datos ubicados a partir de la posición 8 hacia la derecha

print("el comando sum(lista1)/len(lista1) devuelve:", sum(lista1)/len(lista1)) # divide la suma de todos los números de la lista1 para la longitud de la lista1

lista1.append(["gbi6", "bio1", "ikiam"]) # Añade el elemento ["gbi6", "bio1", "ikiam"] al final de la lista
print("tras el append el comando lista1[-1][2] devuelve:", lista1[-1][2]) # devuelve el elemnto ikiam

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1] # se añade la lista original para reestablecerla
print("el comando lista1[5] devuelve:", lista1[5]) # devuelve el dato ubicado en la posición 5 de la lista

lista1.extend(["gbi6", "bio1", "ikiam"]) # Añade uno por uno los 3 elementos "gbi6", "bio1", "ikiam" al final de la lista
print("tras el extend el comando len(lista1) devuelve:", len(lista1))

lista1 = [8.6, 18.0, 19.4, 13.7, 11.1, 10.1, 10.3, 15.6, 14.9, 9.1]  # se reestablece la lista
print("el comando round(sum(lista1)/len(lista1), 3) devuelve:", round(sum(lista1)/len(lista1), 3))# se redondea a la tercera cifra significativa el resultado de sumar todos los números de la lista1 y dividirlos para la longitud de la lista1
# Out:
# se añadieron los diez primeros datos
# el comando lista1[8:] devuelve: [14.9, 9.1]
# el comando sum(lista1)/len(lista1) devuelve: 13.079999999999998
# tras el append el comando lista1[-1][2] devuelve: ikiam
# el comando lista1[5] devuelve: 10.1
# tras el extend el comando len(lista1) devuelve: 13
# el comando round(sum(lista1)/len(lista1), 3) devuelve: 13.08

# %% [markdown]
# ## Ejercicio 9
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# - Una lista de nombre lista1 que tenga a las 10 primeras letras del alfabeto.
#
# Relacione los códigos y las respuestas que salen al ejecutar.

# %%
# Escriba aquí el código

# %% [markdown]
# ## Ejercicio 10
#
# Para este ejercicio tiene que crear previamente lo siguiente:
#
# - Una lista de nombre lista1 que tenga a las 10 primeras letras del alfabeto.
#
# Relacione los códigos y las respuestas que salen al ejecutar.

# %%
lista1 = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"]
print(len(lista1)) # permite saber si tenemos las 10 letras
print()
print("inicia la corrida de códigos:")
# Ejecucion de comandos pedidos en moodle
lista1.append(["gbi6", "bio1", "ikiam"]) # se añade al final de la lista1 ["gbi6", "bio1", "ikiam"] como un solo dato
print(lista1[-1][-1]) # devuelve "ikiam" 

lista1 = ["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"] # Reestablecemos la lista1
print(lista1[2:5]) # devuelve las letras encontradas entre las posiciones 2 y 5 sin tomar en cuenta el limite superior en este caso 5

print(lista1[3]) # devuelve la letra encontrada en la posición 3

lista1.append(["gbi6", "bio1", "ikiam"]) # inserta el elemento "gbi6", "bio1", "ikiam"] al final de la lista1
print(len(lista1)) # imprime la longitud de la lista tras añadir el elemento anterior con append
# Out:
# 10
#
# inicia la corrida de códigos:
# ikiam
# ['c', 'd', 'e']
# d
# 11
